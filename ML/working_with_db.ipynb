# %%
from sqlalchemy import create_engine, text
import pandas as pd
import numpy as np
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from fuzzywuzzy import fuzz
import pickle

# %%
# PostgreSQL connection details
db_url = 'postgresql://terrox:1205@localhost:5432/majduri'
engine = create_engine(db_url)

# %%
engine.connect()

# %%
df = pd.read_sql("SELECT * FROM table_1", engine)

# %%
df.head()
# Out:
#                                               skills       salary_range  \
# 0  warehouse_management crane_operation loading/u...  ₹12,000 - ₹30,000
# 1  order_taking cash_handling multitasking menu_k...   ₹8,000 - ₹20,000
# 2  farming_techniques irrigation basic_machinery_...  ₹10,000 - ₹25,000
# 3  safety_practices electrical_systems welding ve...  ₹15,000 - ₹30,000
# 4  teamwork cooking_techniques time_management fo...  ₹12,000 - ₹25,000
#
#   qualifications     experience            job_title            job_id  \
# 0   NILL or 10th  4_to_11_years          dock_worker  1089840000000000
# 1   NILL or 10th   2_to_7_years               waiter   398454000000000
# 2   NILL or 10th   0_to_9_years  agricultural_worker   481640000000000
# 3    ITI or 10th  9_to_10_years             mechanic   688193000000000
# 4   NILL or 10th   4_to_6_years                 cook   117058000000000
#
#     location  latitude  longitude  work_type job_posting_date preference  \
# 0  osmanabad   15.6066    74.4717  Part-Time       24-04-2022     female
# 1      latur   18.1643    72.8138  Part-Time       19-12-2022     female
# 2  nandurbar   20.0181    78.7996  Full-Time       14-09-2022       male
# 3      akola   16.5614    78.2276  Full-Time       25-02-2023     female
# 4     wardha   21.8120    73.2671  Part-Time       11-10-2022     female
#
#     contact_person         contact  \
# 0     Vihaan Kumar  +91-6338887517
# 1     Vihaan Mehta  +91-8495848693
# 2      Priya Reddy  +91-9800897411
# 3       Neha Gupta  +91-7104739198
# 4  Siddharth Gupta  +91-9723674124
#
#                                             combined
# 0  warehouse_management crane_operation loading/u...
# 1  order_taking cash_handling multitasking menu_k...
# 2  farming_techniques irrigation basic_machinery_...
# 3  safety_practices electrical_systems welding ve...
# 4  teamwork cooking_techniques time_management fo...

# %% [markdown]
# # VECTORIZER

# %%
vectorizer = TfidfVectorizer(stop_words='english')

weights = {"skills" : 5,
           "location" : 1.3,
           "experience" : 3,
           "preference" : 2.5,
           }

# assigning weight to a column to indicate its priority

# %%
df["combined"] = df["skills"] + " " + df["experience"] + " " + df['location'] + " " + df["preference"]

df.iloc[0].iloc[-1]

# combined string in the order -> skills location experience preference (for vectorization)
# Out:
# 'warehouse_management crane_operation loading/unloading 4_to_11_years osmanabad female'

# %%
tfidf_matrix = vectorizer.fit_transform(df["combined"])

# creating a vectorized matrix of size of the dataframe (size of df, total features)

# %%
tfidf_matrix.shape
# Out:
# (9999, 212)

# %%
feature_names = vectorizer.get_feature_names_out()

len(feature_names)
# Out:
# 212

# %%
weight_vector = np.ones(len(feature_names))

# creating an array of 1s of the size of feature_names

# %%
skills_words = " ".join(df["skills"].dropna()).split()
experience_words = " ".join(df["experience"].dropna().astype(str)).split()
location_words = " ".join(df["location"].dropna()).split()
preference_words = " ".join(df["preference"].dropna()).split()

# creating a map of a word and its category
word_category_map = {}

for word in skills_words:
    word_category_map[word] = "skills"

for word in experience_words:
    word_category_map[word] = "experience"

for word in location_words:
    word_category_map[word] = "location"

for word in preference_words:
    word_category_map[word] = "preference"
    
# 
for i, term in enumerate(feature_names):
    category = word_category_map.get(term)  # Get the category of the term
    if category:
        weight_vector[i] *= weights[category] # apply the weight


"""
kinda have to explain this one, no?
here, size of ifidf_matrix is (9999, 193) ie 10000 rows 193 columns, and weight_matrix (193, 1)

dataset has 10000 rows, and our feature_names size is 193, thus we can multiply them (vector product)
"""
tfidf_matrix = tfidf_matrix.multiply(weight_vector)

tfidf_matrix
# Out:
# <COOrdinate sparse matrix of dtype 'float64'
# 	with 70860 stored elements and shape (9999, 212)>

# %%
def location_similarity(loc1, loc2):
    return fuzz.ratio(loc1, loc2) / 100 # value between 0-1

# %%
def recommend_job(skills, experience, location, preference, top_n=30):
    query = "SELECT * FROM table_1"
    df = pd.read_sql(query, engine)

    combined_str = ' '.join(skills) + " " + experience + " " + location + " " + preference
    user_vector = vectorizer.transform([combined_str])
    
    tfidf_similarities = cosine_similarity(user_vector, tfidf_matrix).flatten()

    location_scores = df["location"].apply(lambda job_loc: location_similarity(job_loc, location))

    refined_scores = tfidf_similarities * location_scores

    top_indices = refined_scores.argsort()[-top_n:][::-1]

    return df.iloc[top_indices][["job_title", "skills", "salary_range", "location", "preference", "experience"]]

# %%
recommend_job(['cleaning', 'laundry', 'cooking'], "3_to_4_years", "mumbai", "female")
# Out:
#        job_title                                             skills  \
# 9698        maid                      cleaning laundry organization
# 1102        maid                   laundry time_management cleaning
# 3920        maid   time_management organization attention_to_detail
# 5429        maid  housekeeping cleaning organization laundry tim...
# 1606        maid  time_management attention_to_detail laundry cl...
# 5207        maid  time_management laundry attention_to_detail cl...
# 3168        maid         laundry cleaning housekeeping organization
# 5744        maid  laundry time_management housekeeping cleaning ...
# 9319        maid  laundry attention_to_detail housekeeping clean...
# 6698        maid  laundry time_management organization cleaning ...
# 2248        maid         laundry housekeeping organization cleaning
# 1094        maid  organization attention_to_detail laundry time_...
# 5736        maid  cleaning organization attention_to_detail laun...
# 2325        maid  cleaning attention_to_detail laundry housekeep...
# 9228        maid  attention_to_detail time_management housekeepi...
# 9146        maid  attention_to_detail time_management laundry cl...
# 3567        maid  laundry organization cleaning time_management ...
# 3962        maid  cleaning time_management organization laundry ...
# 6170  jcb_driver  excavation safety_practices vehicle_maintenanc...
# 3214        maid  attention_to_detail organization time_manageme...
# 443         maid  time_management housekeeping organization laun...
# 3232        maid  housekeeping organization time_management laun...
# 4408        maid  time_management housekeeping attention_to_deta...
# 1985        maid  organization laundry housekeeping time_managem...
# 2671        maid          attention_to_detail organization cleaning
# 5182        maid  attention_to_detail laundry time_management or...
# 8778        maid       attention_to_detail cleaning time_management
# 3162        maid          housekeeping attention_to_detail cleaning
# 5444        maid       cleaning time_management attention_to_detail
# 2450        maid          housekeeping cleaning attention_to_detail
#
#            salary_range location preference     experience
# 9698   ₹8,000 - ₹25,000   mumbai     female  5_to_10_years
# 1102   ₹8,000 - ₹25,000   mumbai       both  8_to_10_years
# 3920   ₹8,000 - ₹25,000   mumbai       both   3_to_4_years
# 5429   ₹8,000 - ₹25,000   mumbai     female  9_to_11_years
# 1606   ₹8,000 - ₹25,000   mumbai       male  6_to_10_years
# 5207   ₹8,000 - ₹25,000   mumbai       male   4_to_8_years
# 3168   ₹8,000 - ₹25,000   mumbai       male  7_to_12_years
# 5744   ₹8,000 - ₹25,000   mumbai     female   3_to_5_years
# 9319   ₹8,000 - ₹25,000   mumbai     female   1_to_7_years
# 6698   ₹8,000 - ₹25,000   mumbai     female   2_to_9_years
# 2248   ₹8,000 - ₹25,000   mumbai       male  3_to_10_years
# 1094   ₹8,000 - ₹25,000   mumbai     female  5_to_12_years
# 5736   ₹8,000 - ₹25,000   mumbai       male   7_to_8_years
# 2325   ₹8,000 - ₹25,000   mumbai       male  8_to_10_years
# 9228   ₹8,000 - ₹25,000   mumbai       male   6_to_8_years
# 9146   ₹8,000 - ₹25,000   mumbai       both  2_to_10_years
# 3567   ₹8,000 - ₹25,000   mumbai       both   0_to_9_years
# 3962   ₹8,000 - ₹25,000   mumbai       male   0_to_4_years
# 6170  ₹15,000 - ₹35,000   mumbai       both   3_to_4_years
# 3214   ₹8,000 - ₹25,000   mumbai       both   5_to_7_years
# 443    ₹8,000 - ₹25,000   mumbai       both   4_to_8_years
# 3232   ₹8,000 - ₹25,000   mumbai       male  5_to_11_years
# 4408   ₹8,000 - ₹25,000   mumbai       both   2_to_6_years
# 1985   ₹8,000 - ₹25,000   mumbai       male   4_to_7_years
# 2671   ₹8,000 - ₹25,000   mumbai     female  7_to_10_years
# 5182   ₹8,000 - ₹25,000   mumbai     female   7_to_8_years
# 8778   ₹8,000 - ₹25,000   mumbai       both   7_to_9_years
# 3162   ₹8,000 - ₹25,000   mumbai       male  9_to_10_years
# 5444   ₹8,000 - ₹25,000   mumbai       both  3_to_11_years
# 2450   ₹8,000 - ₹25,000   mumbai       both  2_to_12_years

# %%
def add_job(job_title, skills, salary, location, preference, experience):

    skills_str = ' '.join(skills)
    
    query = text(f"""
    INSERT INTO table_1 (job_title, skills, salary_range, location, preference, experience)
    VALUES ('{job_title}','{skills_str}', '{salary}', '{location}', '{preference}', '{experience}')
    """)
    
    with engine.connect() as conn:
        conn.execute(query, {
            "skills" : skills_str,
            "job_title" : job_title,
            "salary_range" : salary,
            "location" : location,
            "preference" : preference,
            "experience" : experience
        })
        conn.commit()

# %%
add_job('maid', ['cleaning', 'laundry', 'time_management', 'housekeeping'],'₹10,000 - ₹35,000', 'thane', 'female', '0_to_1_years')

# %%
df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 df.head()
#
# NameError: name 'df' is not defined
