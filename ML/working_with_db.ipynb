# %%
from sqlalchemy import create_engine, text
import pandas as pd
import numpy as np
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from fuzzywuzzy import fuzz
import pickle

# %%
# PostgreSQL connection details
# db_url = 'postgresql://postgres:11201_VivekBhalke@localhost:5432/majduri'
db_url = 'postgresql://neondb_owner:npg_E8ISquQk3oRc@ep-delicate-field-a1gajmto-pooler.ap-southeast-1.aws.neon.tech/neondb?sslmode=require'
engine = create_engine(db_url)

# %%
engine.connect()

# %%
query = """SELECT r."id" as recruiterJobId, mlj."title" AS job_title, mlj."description" AS description,
              mlj."salary" AS salary_range,
                  STRING_AGG(mls."name", ' ') AS skills, 
                  r."location", r."preferance" as preference, r."experience", r."qualifications"
           FROM "RecruiterJob" r 
           JOIN "MLJob" mlj ON mlj."id" = r."mlJobId"
           JOIN "RecruiterSkills" rsk ON rsk."recruiterJobId" = r."id"
           JOIN "MLSkill" mls ON mls."id" = rsk."skillId"
           GROUP BY r."id", mlj."title", mlj."salary" ,mlj."description" , r."location", r."preferance", r."experience", r."qualifications";"""
df = pd.read_sql(query, engine)

# df = pd.read_sql('SELECT mlj."title" AS job_title, STRING_AGG(mls."name", ' ') AS skills,r."location" as location,r."preferance" as preferance, r."experience" as experience,r."qualifications" as qualifications FROM "RecruiterJob" r JOIN "MLJob" mlj ON mlj."id" = r."mlJobId" JOIN "RecruiterSkills" rsk ON rsk."recruiterJobId" = r."id" JOIN "MLSkill" mls ON mls."id" = rsk."skillId" GROUP BY r."id", mlj."title" , r."location" , r."preferance",r."experience" , r."qualifications" ;', engine)

# %%
df.head(15)
# Out:
#                recruiterjobid     job_title          description  \
# 0   cm959dlrb002dtl50y1moe0sg      mechanic      mechanic worker
# 1   cm959flw00048tl50lhpcxhnl       janitor       janitor worker
# 2   cm959bk4w0011tl50dvt5o9t1        waiter          waiter role
# 3   cm959f6w80036tl50rot2kjm2      mechanic      mechanic worker
# 4   cm959aizq000otl50fgdztagl   dock_worker          Dock Worker
# 5   cm959fi3k003itl50ob8fx66h       janitor       janitor worker
# 6   cm959ezib002qtl50waq0c4ss        waiter          waiter role
# 7   cm959gk4k0058tl50l71ocm90  hotel_worker  hotel_worker worker
# 8   cm959bpl6001btl50aljypgd5   dock_worker          Dock Worker
# 9   cm957qvd60004tl50ylkkn7ne        waiter          waiter role
# 10  cm959crp2001rtl50o6hmt887    jcb_driver    jcb_driver worker
# 11  cm958u77d000etl50y7zsnw67        waiter          waiter role
# 12  cm959fvfj004ytl50h7jsaejf   dock_worker          Dock Worker
# 13  cm959cji3001jtl50hm88kusw   dock_worker          Dock Worker
#
#          salary_range                                             skills  \
# 0   ₹15,000 - ₹30,000      vehicle_maintenance engine_repair diagnostics
# 1    ₹8,000 - ₹20,000  cleaning facility_maintenance waste_disposal s...
# 2    ₹8,000 - ₹20,000           cash_handling communication multitasking
# 3   ₹15,000 - ₹30,000  vehicle_maintenance engine_repair diagnostics ...
# 4   ₹12,000 - ₹30,000  loading/unloading crane_operation warehouse_ma...
# 5    ₹8,000 - ₹20,000  cleaning facility_maintenance waste_disposal s...
# 6    ₹8,000 - ₹20,000  cash_handling communication multitasking menu_...
# 7   ₹12,000 - ₹30,000      customer_service hospitality room_maintenance
# 8   ₹12,000 - ₹30,000                  loading/unloading crane_operation
# 9    ₹8,000 - ₹20,000           cash_handling communication multitasking
# 10  ₹15,000 - ₹35,000  heavy_machinery_operation site_preparation exc...
# 11   ₹8,000 - ₹20,000           cash_handling communication multitasking
# 12  ₹12,000 - ₹30,000  loading/unloading crane_operation warehouse_ma...
# 13  ₹12,000 - ₹30,000                  loading/unloading crane_operation
#
#      location preference    experience qualifications
# 0   ahmedabad     Female  1_to_2_years           NILL
# 1       thane       Male  1_to_3_years           NILL
# 2      mumbai       Male  1_to_6_years           NILL
# 3       thane       Male  1_to_2_years           NILL
# 4      mumbai       Male  1_to_5_years           NILL
# 5       thane     Female  1_to_3_years           NILL
# 6       thane       Male  1_to_2_years           NILL
# 7       thane     Female  1_to_5_years           NILL
# 8      mumbai       Male  1_to_6_years           NILL
# 9        pune       Male  1_to_4_years         1_to_4
# 10  ahmedabad       Male  1_to_1_years           NILL
# 11       pune       Male  1_to_5_years           NILL
# 12      thane       Male  1_to_5_years           NILL
# 13  ahmedabad       Male  1_to_6_years           NILL

# %% [markdown]
# # VECTORIZER

# %%
vectorizer = TfidfVectorizer(stop_words='english')

weights = {"skills" : 5,
           "location" : 1.3,
           "experience" : 3,
           "preference" : 2.5,
           }

# assigning weight to a column to indicate its priority

# %%
df["combined"] = df["skills"] + " " + df["experience"] + " " + df['location'] + " " + df["preference"]

df.iloc[0].iloc[-1]

# combined string in the order -> skills location experience preference (for vectorization)
# Out:
# 'customer_service hospitality room_maintenance 1_to_5_years thane Female'

# %%
tfidf_matrix = vectorizer.fit_transform(df["combined"])

# creating a vectorized matrix of size of the dataframe (size of df, total features)

# %%
tfidf_matrix.shape
# Out:
# (14, 42)

# %%
feature_names = vectorizer.get_feature_names_out()

len(feature_names)
# Out:
# 42

# %%
weight_vector = np.ones(len(feature_names))

# creating an array of 1s of the size of feature_names

# %%
df.columns
# Out:
# Index(['recruiterjobid', 'job_title', 'salary_range', 'skills', 'location',
#        'preference', 'experience', 'qualifications', 'combined'],
#       dtype='object')

# %%
skills_words = " ".join(df["skills"].dropna()).split()
experience_words = " ".join(df["experience"].dropna().astype(str)).split()
location_words = " ".join(df["location"].dropna()).split()
preference_words = " ".join(df["preference"].dropna()).split()

# creating a map of a word and its category
word_category_map = {}

for word in skills_words:
    word_category_map[word] = "skills"

for word in experience_words:
    word_category_map[word] = "experience"

for word in location_words:
    word_category_map[word] = "location"

for word in preference_words:
    word_category_map[word] = "preference"
    
# 
for i, term in enumerate(feature_names):
    category = word_category_map.get(term)  # Get the category of the term
    if category:
        weight_vector[i] *= weights[category] # apply the weight


"""
kinda have to explain this one, no?
here, size of ifidf_matrix is (9999, 193) ie 10000 rows 193 columns, and weight_matrix (193, 1)

dataset has 10000 rows, and our feature_names size is 193, thus we can multiply them (vector product)
"""
tfidf_matrix = tfidf_matrix.multiply(weight_vector)

tfidf_matrix
# Out:
# <COOrdinate sparse matrix of dtype 'float64'
# 	with 106 stored elements and shape (14, 42)>

# %%
def location_similarity(loc1, loc2):
    return fuzz.ratio(loc1, loc2) / 100 # value between 0-1

# %%
def recommend_job(skills, experience, location, preference, top_n=30):
    # query = """SELECT mlj."title" AS job_title, 
    #           mlj."salary" AS salary_range,
    #               STRING_AGG(mls."name", ' ') AS skills, 
    #               r."location", r."preferance" as preference, r."experience", r."qualifications"
    #        FROM "RecruiterJob" r 
    #        JOIN "MLJob" mlj ON mlj."id" = r."mlJobId"
    #        JOIN "RecruiterSkills" rsk ON rsk."recruiterJobId" = r."id"
    #        JOIN "MLSkill" mls ON mls."id" = rsk."skillId"
    #        GROUP BY r."id", mlj."title", mlj."salary" , r."location", r."preferance", r."experience", r."qualifications";"""
    # df = pd.read_sql(query, engine)

    combined_str = ' '.join(skills) + " " + experience + " " + location + " " + preference
    user_vector = vectorizer.transform([combined_str])
    
    tfidf_similarities = cosine_similarity(user_vector, tfidf_matrix).flatten()

    location_scores = df["location"].apply(lambda job_loc: location_similarity(job_loc, location))

    refined_scores = tfidf_similarities * location_scores

    top_indices = refined_scores.argsort()[-top_n:][::-1]

    return df.iloc[top_indices][["recruiterjobid","job_title", "skills", "salary_range", "location", "preference", "experience"]]

# %%
recommend_job(['cleaning', 'laundry', 'cooking'], "3_to_4_years", "mumbai", "female")
# Out:
#                recruiterjobid     job_title  \
# 9   cm959bpl6001btl50aljypgd5   dock_worker
# 12  cm959aizq000otl50fgdztagl   dock_worker
# 1   cm959bk4w0011tl50dvt5o9t1        waiter
# 13  cm959fi3k003itl50ob8fx66h       janitor
# 6   cm959flw00048tl50lhpcxhnl       janitor
# 3   cm959dlrb002dtl50y1moe0sg      mechanic
# 0   cm959gk4k0058tl50l71ocm90  hotel_worker
# 8   cm959cji3001jtl50hm88kusw   dock_worker
# 11  cm957qvd60004tl50ylkkn7ne        waiter
# 10  cm958u77d000etl50y7zsnw67        waiter
# 4   cm959ezib002qtl50waq0c4ss        waiter
# 5   cm959fvfj004ytl50h7jsaejf   dock_worker
# 7   cm959f6w80036tl50rot2kjm2      mechanic
# 2   cm959crp2001rtl50o6hmt887    jcb_driver
#
#                                                skills       salary_range  \
# 9                   loading/unloading crane_operation  ₹12,000 - ₹30,000
# 12  loading/unloading crane_operation warehouse_ma...  ₹12,000 - ₹30,000
# 1            cash_handling communication multitasking   ₹8,000 - ₹20,000
# 13  cleaning facility_maintenance waste_disposal s...   ₹8,000 - ₹20,000
# 6   cleaning facility_maintenance waste_disposal s...   ₹8,000 - ₹20,000
# 3       vehicle_maintenance engine_repair diagnostics  ₹15,000 - ₹30,000
# 0       customer_service hospitality room_maintenance  ₹12,000 - ₹30,000
# 8                   loading/unloading crane_operation  ₹12,000 - ₹30,000
# 11           cash_handling communication multitasking   ₹8,000 - ₹20,000
# 10           cash_handling communication multitasking   ₹8,000 - ₹20,000
# 4   cash_handling communication multitasking menu_...   ₹8,000 - ₹20,000
# 5   loading/unloading crane_operation warehouse_ma...  ₹12,000 - ₹30,000
# 7   vehicle_maintenance engine_repair diagnostics ...  ₹15,000 - ₹30,000
# 2   heavy_machinery_operation site_preparation exc...  ₹15,000 - ₹35,000
#
#      location preference    experience
# 9      mumbai       Male  1_to_6_years
# 12     mumbai       Male  1_to_5_years
# 1      mumbai       Male  1_to_6_years
# 13      thane     Female  1_to_3_years
# 6       thane       Male  1_to_3_years
# 3   ahmedabad     Female  1_to_2_years
# 0       thane     Female  1_to_5_years
# 8   ahmedabad       Male  1_to_6_years
# 11       pune       Male  1_to_4_years
# 10       pune       Male  1_to_5_years
# 4       thane       Male  1_to_2_years
# 5       thane       Male  1_to_5_years
# 7       thane       Male  1_to_2_years
# 2   ahmedabad       Male  1_to_1_years

# %%
with open("vectorizer.pkl", 'wb') as file:
    pickle.dump(vectorizer, file)

with open("matrix.pkl", 'wb') as file:
    pickle.dump(tfidf_matrix, file)

# %%
def add_job(job_title, skills, salary, location, preference, experience):

    skills_str = ' '.join(skills)
    
    query = text(f"""
    INSERT INTO table_1 (job_title, skills, salary_range, location, preference, experience)
    VALUES ('{job_title}','{skills_str}', '{salary}', '{location}', '{preference}', '{experience}')
    """)
    
    with engine.connect() as conn:
        conn.execute(query, {
            "skills" : skills_str,
            "job_title" : job_title,
            "salary_range" : salary,
            "location" : location,
            "preference" : preference,
            "experience" : experience
        })
        conn.commit()

# %%
add_job('maid', ['cleaning', 'laundry', 'time_management', 'housekeeping'],'₹10,000 - ₹35,000', 'thane', 'female', '0_to_1_years')

# %%
df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 df.head()
#
# NameError: name 'df' is not defined
